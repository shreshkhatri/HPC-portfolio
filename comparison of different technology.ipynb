# %%
import matplotlib.pyplot as pyp

# %%
  #######################################################################
 #   PASSWORD CRACKING : POSIX VS SEQUENTIAL VS CUDA                   #
#######################################################################

X1=['Sequential\n']
X2=['POSIX\n'] 
X3=['CUDA\n']

Y1=[506.87]
Y2=[260.53]
Y3=[0.074]

pyp.bar(X1,Y1,label='Sequential')
pyp.bar(X2,Y2,label='POSIX')
pyp.bar(X3,Y3,label='CUDA')
pyp.xlabel('Parallel computing Technologies')
pyp.ylabel('Mean execution time (in seconds )')
pyp.title('Mean execution time for differnt Parallel computing Technology\nFor Password Cracking Program\n')
pyp.legend()
pyp.show()

# %%
  #######################################################################
 #   IMAGE PROCESSING : SEQUNTIAL VS POSIX VS CUDA                   #
#######################################################################
X1=['Sequential\n']
X2=['POSIX\n'] 
X3=['CUDA\n']

Y1=[.193]
Y2=[.64]
Y3=[.187]

pyp.bar(X1,Y1,label='Sequential')
pyp.bar(X2,Y2,label='POSIX')
pyp.bar(X3,Y3,label='CUDA')
pyp.xlabel('Parallel computing Technologies')
pyp.ylabel('Mean execution time (in milliseconds )')
pyp.title('Mean execution time for differnt Parallel computing Technology\nFor Image Processing Program\n')
pyp.legend()
pyp.show()

# %%
  #######################################################################
 #   LINEAR REGRESSION  : SEQUNTIAL VS POSIX VS CUDA                   #
#######################################################################
X1=['Sequential\n']
X2=['POSIX\n'] 
X3=['CUDA\n']

Y1=[.4]
Y2=[.92]
Y3=[.25]

pyp.bar(X1,Y1,label='Sequential')
pyp.bar(X2,Y2,label='POSIX')
pyp.bar(X3,Y3,label='CUDA')
pyp.xlabel('Parallel computing Technologies')
pyp.ylabel('Mean execution time (in seconds )')
pyp.title('Mean execution time for differnt Parallel computing Technology\nFor Linear Regression Program\n')
pyp.legend()
pyp.show()

# %%
  #######################################################################
 #   IMAGE PROCESSING : SEQUNTIAL VS POSIX VS CUDA VS MPI              #
#######################################################################
X1=['Sequential\n']
X2=['POSIX\n'] 
X3=['CUDA\n']
X4=['MPI\n']

Y1=[.193]
Y2=[.64]
Y3=[.18]
Y4=[1.54]

pyp.bar(X1,Y1,label='Sequential')
pyp.bar(X2,Y2,label='POSIX')
pyp.bar(X3,Y3,label='CUDA')
pyp.bar(X4,Y4,label='MPI')
pyp.xlabel('Parallel computing Technologies')
pyp.ylabel('Mean execution time (in milliseconds )')
pyp.title('Mean execution time for differnt Parallel computing Technology\nFor Image Processing Program\n')
pyp.legend()
pyp.show()

# %%
  #######################################################################
 #   LINEAR REGRESSION  : SEQUNTIAL VS POSIX VS CUDA VS MPI                 #
#######################################################################
X1=['Sequential\n']
X2=['POSIX\n'] 
X3=['CUDA\n']
X4=['MPI\n']

Y1=[42.7]
Y2=[922.03]
Y3=[251.9]
Y4=[991.56]

pyp.bar(X1,Y1,label='Sequential')
pyp.bar(X2,Y2,label='POSIX')
pyp.bar(X3,Y3,label='CUDA')
pyp.bar(X4,Y4,label='MPI')

pyp.xlabel('Parallel computing Technologies')
pyp.ylabel('Mean execution time (in milliseconds )')
pyp.title('Mean execution time for differnt Parallel computing Technology\nFor Linear Regression Program\n')
pyp.legend()
pyp.show()
